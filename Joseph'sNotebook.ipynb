# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv('df_electronics.csv')
# Out:
#          item_id  user_id  rating   timestamp model_attr  \
# 0              0        0     5.0  1999-06-13     Female
# 1              0        1     5.0  1999-06-14     Female
# 2              0        2     3.0  1999-06-17     Female
# 3              0        3     1.0  1999-07-01     Female
# 4              0        4     2.0  1999-07-06     Female
# ...          ...      ...     ...         ...        ...
# 1292949     9478  1157628     1.0  2018-09-26     Female
# 1292950     9435  1157629     5.0  2018-09-26     Female
# 1292951     9305  1157630     3.0  2018-09-26     Female
# 1292952     9303  1157631     5.0  2018-09-29       Male
# 1292953     9478  1157632     1.0  2018-10-01     Female
#
#                         category       brand  year user_attr  split
# 0         Portable Audio & Video         NaN  1999       NaN      0
# 1         Portable Audio & Video         NaN  1999       NaN      0
# 2         Portable Audio & Video         NaN  1999       NaN      0
# ...

# %%
pd.read_csv('df_modcloth.csv')
# Out:
#        item_id       user_id  rating                         timestamp  size  \
# 0         7443          Alex       4         2010-01-21 08:00:00+00:00   NaN
# 1         7443  carolyn.agan       3         2010-01-27 08:00:00+00:00   NaN
# 2         7443         Robyn       4         2010-01-29 08:00:00+00:00   NaN
# 3         7443            De       4         2010-02-13 08:00:00+00:00   NaN
# 4         7443         tasha       4         2010-02-18 08:00:00+00:00   NaN
# ...        ...           ...     ...                               ...   ...
# 99888   154797     BernMarie       5  2019-06-26 21:15:13.165000+00:00   6.0
# 99889    77949           Sam       4  2019-06-26 23:22:29.633000+00:00   4.0
# 99890    67194        Janice       5  2019-06-27 00:20:52.125000+00:00   NaN
# 99891    71607           amy       3  2019-06-27 15:45:06.250000+00:00   NaN
# 99892   119732         sarah       3  2019-06-29 13:55:16.542000+00:00   NaN
#
# ...

# %%
import gzip
import json

def parse(path):
    with gzip.open(path, 'rt', encoding='utf-8') as g:
        for line in g:
            yield json.loads(line)

df_mod = []
df_rent = []

for i, entry in enumerate(parse('modcloth_final_data.json.gz')):
    df_mod.append(entry)


for i, entry in enumerate(parse('renttherunway_final_data.json.gz')):
    df_rent.append(entry)

# %%
df_mod[82785]
# Out:
# {'item_id': '807722',
#  'shoe size': '8.50',
#  'size': 8,
#  'quality': 4,
#  'shoe width': 'average',
#  'cup size': 'b',
#  'bra size': '36',
#  'review_summary': 'Cute jacket!',
#  'category': 'outerwear',
#  'length': 'just right',
#  'height': '5ft 8in',
#  'user_name': 'Jennifer',
#  'review_text': 'Cute jacket!',
#  'fit': 'fit',
#  'user_id': '727820'}

# %%
df_mod = pd.read_json('modcloth_final_data.json.gz', compression='gzip', lines=True)
print(len(df_mod))
df_mod.head()
# Out:
# 82790
#    item_id  waist  size  quality cup size  hips  bra size category bust  \
# 0   123373   29.0     7      5.0        d  38.0      34.0      new   36
# 1   123373   31.0    13      3.0        b  30.0      36.0      new  NaN
# 2   123373   30.0     7      2.0        b   NaN      32.0      new  NaN
# 3   123373    NaN    21      5.0     dd/e   NaN       NaN      new  NaN
# 4   123373    NaN    18      5.0        b   NaN      36.0      new  NaN
#
#     height         user_name         length    fit  user_id  shoe size  \
# 0  5ft 6in             Emily     just right  small   991571        NaN
# 1  5ft 2in  sydneybraden2001     just right  small   587883        NaN
# 2  5ft 7in             Ugggh  slightly long  small   395665        9.0
# 3      NaN      alexmeyer626     just right    fit   875643        NaN
# 4  5ft 2in        dberrones1  slightly long  small   944840        NaN
#
#   shoe width review_summary review_text
# 0        NaN            NaN         NaN
# ...

# %%
df_mod.dropna()
# Out:
#        item_id  waist  size  quality cup size  hips  bra size   category bust  \
# 7872    154411   34.0    15      5.0    ddd/f  42.0      38.0        new   42
# 7873    154411   27.0     8      5.0        b  37.0      34.0        new   34
# 8366    155981   30.0     8      5.0        b  41.0      34.0        new   36
# 8450    157334   26.0     8      5.0        d  38.0      32.0        new   34
# 8473    159706   28.0    12      4.0        b  38.0      34.0        new   36
# ...        ...    ...   ...      ...      ...   ...       ...        ...  ...
# 80851   800975   31.0    15      2.0    ddd/f  39.0      36.0       sale   39
# 80932   801763   36.0    15      3.0        d  42.0      38.0  outerwear   44
# 80942   803464   30.0     8      1.0        c  40.0      36.0  outerwear   35
# 82654   807252   30.0    20      5.0        b  39.0      42.0  outerwear   32
# 82720   807384   38.0    26      5.0        c  50.0      38.0  outerwear   43
#
# ...

# %%
set(df_mod['category'])
# Out:
# {'bottoms', 'dresses', 'new', 'outerwear', 'sale', 'tops', 'wedding'}

# %%
set(df_mod['length'])
# Out:
# {'just right',
#  nan,
#  'slightly long',
#  'slightly short',
#  'very long',
#  'very short'}

# %%
set(df_mod['fit'])
# Out:
# {'fit', 'large', 'small'}

# %%
df_rent = pd.read_json('renttherunway_final_data.json.gz', compression='gzip', lines=True)
print(len(df_rent))
df_rent.head()
# Out:
# 192544
#    fit  user_id bust size  item_id  weight  rating     rented for  \
# 0  fit   420272       34d  2260466  137lbs    10.0       vacation
# 1  fit   273551       34b   153475  132lbs    10.0          other
# 2  fit   360448       NaN  1063761     NaN    10.0          party
# 3  fit   909926       34c   126335  135lbs     8.0  formal affair
# 4  fit   151944       34b   616682  145lbs    10.0        wedding
#
#                                          review_text          body type  \
# 0  An adorable romper! Belt and zipper were a lit...          hourglass
# 1  I rented this dress for a photo shoot. The the...  straight & narrow
# 2  This hugged in all the right places! It was a ...                NaN
# 3  I rented this for my company's black tie award...               pear
# 4  I have always been petite in my upper body and...           athletic
#
#                                       review_summary category height  size  \
# ...

# %%
def weight_clean(row):
    try:
        return int(row.split('l')[0])
    except:
        return np.nan
df_rent['weight'] = df_rent['weight'].apply(weight_clean)

# %%
# plotting histogram of companies and the years they were founded
plt.figure(figsize=(6, 4))
plt.hist(df_rent['weight'], bins=20, edgecolor='black')
plt.xlabel('Weight (lbs)')
plt.ylabel('Frequency')
plt.title('Distribution of Weights')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
# plotting histogram of companies and the years they were founded
plt.figure(figsize=(6, 4))
plt.hist(df_rent['size'], bins=20, edgecolor='black')
plt.xlabel('Size')
plt.ylabel('Frequency')
plt.title('Distribution of Size Purchased')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
# plotting histogram of companies and the years they were founded
plt.figure(figsize=(6, 4))
plt.hist(df_rent['age'], bins=20, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age Purchased')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
# countplot of number of companies in each employment type
plt.figure(figsize=(8, 6))
sns.countplot(y='rented for', data=df_rent, palette='viridis')
plt.title('Distribution of Rented For')
plt.xlabel('Count')
plt.ylabel('Occasion Type')
plt.show()
# Out:
# /var/folders/ff/q2zj5x0j7hn_28kmlfc158t00000gn/T/ipykernel_76724/332011398.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='rented for', data=df_rent, palette='viridis')

# %%
# countplot of number of companies in each employment type
plt.figure(figsize=(8, 6))
sns.countplot(y='height', data=df_rent, palette='viridis')
plt.title('Distribution of Category')
plt.xlabel('Count')
plt.ylabel('Occasion Type')
plt.show()
# Out:
# /var/folders/ff/q2zj5x0j7hn_28kmlfc158t00000gn/T/ipykernel_76724/1521379304.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='height', data=df_rent, palette='viridis')

# %%
# scatter plot of average company rating vs salary_avg_estimate_per_year
plt.figure(figsize=(10, 6))
plt.box(df_rent['age'], df_rent['rating'], alpha=0.5)
plt.xlabel('Age')
plt.ylabel('Rating')
plt.title('Age vs Rating')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 3
#       1 # scatter plot of average company rating vs salary_avg_estimate_per_year
#       2 plt.figure(figsize=(10, 6))
# ----> 3 plt.boxplot(df_rent['age'], df_rent['rating'], alpha=0.5)
#       4 plt.xlabel('Age')
#       5 plt.ylabel('Rating')
#
# File /opt/homebrew/Cellar/jupyterlab/4.1.1/libexec/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:300, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     295     warn_deprecated(
#     296         since, message=f"The {old!r} parameter of {func.__name__}() "
#     297         f"has been renamed {new!r} since Matplotlib {since}; support "
#     298         f"for the old name will be dropped %(removal)s.")
#     299     kwargs[new] = kwargs.pop(old)
# --> 300 return func(*args, **kwargs)
#
# ...
